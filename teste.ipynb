# %%
import pandas as pd

from config.consulta import *

# %%
df_funcionario, df_empresa, df_rotas = get_query()

# %%
df_rotas.head()
# Out:
#    id_rota  id_empresa  mes   ano aeroporto_de_origem_sigla  \
# 0        1           3    1  2000                      SBBH
# 1        2           3    1  2000                      SBBH
# 2      468           3    2  2000                      SBVT
# 3      469           3    3  2000                      SBBH
# 4      470           3    3  2000                      SBCT
#
#   aeroporto_de_origem_nome aeroporto_de_origem_uf aeroporto_de_origem_regiao  \
# 0           BELO HORIZONTE                     MG                    SUDESTE
# 1           BELO HORIZONTE                     MG                    SUDESTE
# 2                  VITORIA                     ES                    SUDESTE
# 3           BELO HORIZONTE                     MG                    SUDESTE
# 4     SAO JOSE DOS PINHAIS                     PR                        SUL
#
#   aeroporto_de_origem_pais aeroporto_de_origem_continente  ...  \
# 0                   BRASIL                 AMERICA DO SUL  ...
# ...
